# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
data = pd.read_csv("Car details v3.csv")
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 0     Individual       Manual           First Owner   23.4 kmpl  1248 CC
# 1     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 2     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 3     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 4     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# ...          ...          ...                   ...         ...      ...
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats
# 0         74 bhp             190Nm@ 2000rpm    5.0
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0
# ...          ...                        ...    ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0
#
# [8128 rows x 13 columns]

# %%
data.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
data.name.value_counts()
# Out:
# Maruti Swift Dzire VDI               129
# Maruti Alto 800 LXI                   82
# Maruti Alto LXi                       71
# BMW X4 M Sport X xDrive20d            62
# Maruti Swift VDI                      61
#                                     ...
# Mahindra KUV 100 G80 K4 Plus 5Str      1
# Maruti Swift ZXI BSIII                 1
# Hyundai Getz 1.3 GVS                   1
# Hyundai i20 Era 1.2                    1
# Tata Sumo CX 10 Str BSIV               1
# Name: name, Length: 2058, dtype: int64

# %%
car=data.name.str.split(expand=True)
cartype=car[0]
data['cartype']=cartype
data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission                 owner     mileage   engine  \
# 0     Individual       Manual           First Owner   23.4 kmpl  1248 CC
# 1     Individual       Manual          Second Owner  21.14 kmpl  1498 CC
# 2     Individual       Manual           Third Owner   17.7 kmpl  1497 CC
# 3     Individual       Manual           First Owner   23.0 kmpl  1396 CC
# 4     Individual       Manual           First Owner   16.1 kmpl  1298 CC
# ...          ...          ...                   ...         ...      ...
# 8123  Individual       Manual           First Owner   18.5 kmpl  1197 CC
# 8124  Individual       Manual  Fourth & Above Owner   16.8 kmpl  1493 CC
# 8125  Individual       Manual           First Owner   19.3 kmpl  1248 CC
# 8126  Individual       Manual           First Owner  23.57 kmpl  1396 CC
# 8127  Individual       Manual           First Owner  23.57 kmpl  1396 CC
#
#        max_power                     torque  seats  cartype
# 0         74 bhp             190Nm@ 2000rpm    5.0   Maruti
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0    Skoda
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0    Honda
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0  Hyundai
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0   Maruti
# ...          ...                        ...    ...      ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0  Hyundai
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0  Hyundai
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0   Maruti
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0     Tata
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0     Tata
#
# [8128 rows x 14 columns]

# %%
data.cartype.value_counts()
# Out:
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Ambassador          4
# Kia                 4
# Daewoo              3
# MG                  3
# Ashok               1
# Peugeot             1
# Opel                1
# Name: cartype, dtype: int64

# %%
data = data.drop(['name'],axis=1)

# %%
today=datetime.today()
curr_year=today.year
data['No. of years']=curr_year-data['year']
data=data.drop(['year'],axis=1)
data
# Out:
#       selling_price  km_driven    fuel seller_type transmission  \
# 0            450000     145500  Diesel  Individual       Manual
# 1            370000     120000  Diesel  Individual       Manual
# 2            158000     140000  Petrol  Individual       Manual
# 3            225000     127000  Diesel  Individual       Manual
# 4            130000     120000  Petrol  Individual       Manual
# ...             ...        ...     ...         ...          ...
# 8123         320000     110000  Petrol  Individual       Manual
# 8124         135000     119000  Diesel  Individual       Manual
# 8125         382000     120000  Diesel  Individual       Manual
# 8126         290000      25000  Diesel  Individual       Manual
# 8127         290000      25000  Diesel  Individual       Manual
#
#                      owner     mileage   engine   max_power  \
# 0              First Owner   23.4 kmpl  1248 CC      74 bhp
# 1             Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2              Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3              First Owner   23.0 kmpl  1396 CC      90 bhp
# 4              First Owner   16.1 kmpl  1298 CC    88.2 bhp
# ...                    ...         ...      ...         ...
# 8123           First Owner   18.5 kmpl  1197 CC   82.85 bhp
# 8124  Fourth & Above Owner   16.8 kmpl  1493 CC     110 bhp
# 8125           First Owner   19.3 kmpl  1248 CC    73.9 bhp
# 8126           First Owner  23.57 kmpl  1396 CC      70 bhp
# 8127           First Owner  23.57 kmpl  1396 CC      70 bhp
#
#                          torque  seats  cartype  No. of years
# 0                190Nm@ 2000rpm    5.0   Maruti             7
# 1           250Nm@ 1500-2500rpm    5.0    Skoda             7
# 2         12.7@ 2,700(kgm@ rpm)    5.0    Honda            15
# 3      22.4 kgm at 1750-2750rpm    5.0  Hyundai            11
# 4         11.5@ 4,500(kgm@ rpm)    5.0   Maruti            14
# ...                         ...    ...      ...           ...
# 8123           113.7Nm@ 4000rpm    5.0  Hyundai             8
# 8124  24@ 1,900-2,750(kgm@ rpm)    5.0  Hyundai            14
# 8125             190Nm@ 2000rpm    5.0   Maruti            12
# 8126        140Nm@ 1800-3000rpm    5.0     Tata             8
# 8127        140Nm@ 1800-3000rpm    5.0     Tata             8
#
# [8128 rows x 13 columns]

# %%
data.fuel.value_counts()
# Out:
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: fuel, dtype: int64

# %%
data.seller_type.value_counts()
# Out:
# Individual          6766
# Dealer              1126
# Trustmark Dealer     236
# Name: seller_type, dtype: int64

# %%
data.transmission.value_counts()
# Out:
# Manual       7078
# Automatic    1050
# Name: transmission, dtype: int64

# %%
data.owner.value_counts()
# Out:
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: owner, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data.fuel=le.fit_transform(data.fuel)
data.seller_type=le.fit_transform(data.seller_type)
data.transmission=le.fit_transform(data.transmission)
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  \
# 0            450000     145500     1            1             1
# 1            370000     120000     1            1             1
# 2            158000     140000     3            1             1
# 3            225000     127000     1            1             1
# 4            130000     120000     3            1             1
# ...             ...        ...   ...          ...           ...
# 8123         320000     110000     3            1             1
# 8124         135000     119000     1            1             1
# 8125         382000     120000     1            1             1
# 8126         290000      25000     1            1             1
# 8127         290000      25000     1            1             1
#
#                      owner     mileage   engine   max_power  \
# 0              First Owner   23.4 kmpl  1248 CC      74 bhp
# 1             Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2              Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3              First Owner   23.0 kmpl  1396 CC      90 bhp
# 4              First Owner   16.1 kmpl  1298 CC    88.2 bhp
# ...                    ...         ...      ...         ...
# 8123           First Owner   18.5 kmpl  1197 CC   82.85 bhp
# 8124  Fourth & Above Owner   16.8 kmpl  1493 CC     110 bhp
# 8125           First Owner   19.3 kmpl  1248 CC    73.9 bhp
# 8126           First Owner  23.57 kmpl  1396 CC      70 bhp
# 8127           First Owner  23.57 kmpl  1396 CC      70 bhp
#
#                          torque  seats  cartype  No. of years
# 0                190Nm@ 2000rpm    5.0   Maruti             7
# 1           250Nm@ 1500-2500rpm    5.0    Skoda             7
# 2         12.7@ 2,700(kgm@ rpm)    5.0    Honda            15
# 3      22.4 kgm at 1750-2750rpm    5.0  Hyundai            11
# 4         11.5@ 4,500(kgm@ rpm)    5.0   Maruti            14
# ...                         ...    ...      ...           ...
# 8123           113.7Nm@ 4000rpm    5.0  Hyundai             8
# 8124  24@ 1,900-2,750(kgm@ rpm)    5.0  Hyundai            14
# 8125             190Nm@ 2000rpm    5.0   Maruti            12
# 8126        140Nm@ 1800-3000rpm    5.0     Tata             8
# 8127        140Nm@ 1800-3000rpm    5.0     Tata             8
#
# [8128 rows x 13 columns]

# %%
data=data.replace({'owner':{'First Owner':1,
                     'Second Owner':2,
                     'Third Owner':3,
                     'Fourth & Above Owner':4,
                      'Test Drive Car':5}})
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0            450000     145500     1            1             1      1
# 1            370000     120000     1            1             1      2
# 2            158000     140000     3            1             1      3
# 3            225000     127000     1            1             1      1
# 4            130000     120000     3            1             1      1
# ...             ...        ...   ...          ...           ...    ...
# 8123         320000     110000     3            1             1      1
# 8124         135000     119000     1            1             1      4
# 8125         382000     120000     1            1             1      1
# 8126         290000      25000     1            1             1      1
# 8127         290000      25000     1            1             1      1
#
#          mileage   engine   max_power                     torque  seats  \
# 0      23.4 kmpl  1248 CC      74 bhp             190Nm@ 2000rpm    5.0
# 1     21.14 kmpl  1498 CC  103.52 bhp        250Nm@ 1500-2500rpm    5.0
# 2      17.7 kmpl  1497 CC      78 bhp      12.7@ 2,700(kgm@ rpm)    5.0
# 3      23.0 kmpl  1396 CC      90 bhp   22.4 kgm at 1750-2750rpm    5.0
# 4      16.1 kmpl  1298 CC    88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0
# ...          ...      ...         ...                        ...    ...
# 8123   18.5 kmpl  1197 CC   82.85 bhp           113.7Nm@ 4000rpm    5.0
# 8124   16.8 kmpl  1493 CC     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 8125   19.3 kmpl  1248 CC    73.9 bhp             190Nm@ 2000rpm    5.0
# 8126  23.57 kmpl  1396 CC      70 bhp        140Nm@ 1800-3000rpm    5.0
# 8127  23.57 kmpl  1396 CC      70 bhp        140Nm@ 1800-3000rpm    5.0
#
#       cartype  No. of years
# 0      Maruti             7
# 1       Skoda             7
# 2       Honda            15
# 3     Hyundai            11
# 4      Maruti            14
# ...       ...           ...
# 8123  Hyundai             8
# 8124  Hyundai            14
# 8125   Maruti            12
# 8126     Tata             8
# 8127     Tata             8
#
# [8128 rows x 13 columns]

# %%
mileage_alter=data.mileage.str.split(expand=True)
mileage_new=mileage_alter[0]
data['Mileage']=mileage_new
data=data.drop(['mileage'],axis=1)
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0            450000     145500     1            1             1      1
# 1            370000     120000     1            1             1      2
# 2            158000     140000     3            1             1      3
# 3            225000     127000     1            1             1      1
# 4            130000     120000     3            1             1      1
# ...             ...        ...   ...          ...           ...    ...
# 8123         320000     110000     3            1             1      1
# 8124         135000     119000     1            1             1      4
# 8125         382000     120000     1            1             1      1
# 8126         290000      25000     1            1             1      1
# 8127         290000      25000     1            1             1      1
#
#        engine   max_power                     torque  seats  cartype  \
# 0     1248 CC      74 bhp             190Nm@ 2000rpm    5.0   Maruti
# 1     1498 CC  103.52 bhp        250Nm@ 1500-2500rpm    5.0    Skoda
# 2     1497 CC      78 bhp      12.7@ 2,700(kgm@ rpm)    5.0    Honda
# 3     1396 CC      90 bhp   22.4 kgm at 1750-2750rpm    5.0  Hyundai
# 4     1298 CC    88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0   Maruti
# ...       ...         ...                        ...    ...      ...
# 8123  1197 CC   82.85 bhp           113.7Nm@ 4000rpm    5.0  Hyundai
# 8124  1493 CC     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0  Hyundai
# 8125  1248 CC    73.9 bhp             190Nm@ 2000rpm    5.0   Maruti
# 8126  1396 CC      70 bhp        140Nm@ 1800-3000rpm    5.0     Tata
# 8127  1396 CC      70 bhp        140Nm@ 1800-3000rpm    5.0     Tata
#
#       No. of years Mileage
# 0                7    23.4
# 1                7   21.14
# 2               15    17.7
# 3               11    23.0
# 4               14    16.1
# ...            ...     ...
# 8123             8    18.5
# 8124            14    16.8
# 8125            12    19.3
# 8126             8   23.57
# 8127             8   23.57
#
# [8128 rows x 13 columns]

# %%
engine_alter=data.engine.str.split(expand=True)
engine_new = engine_alter[0]
data['Engine']=engine_new
data=data.drop(['engine'],axis=1)
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0            450000     145500     1            1             1      1
# 1            370000     120000     1            1             1      2
# 2            158000     140000     3            1             1      3
# 3            225000     127000     1            1             1      1
# 4            130000     120000     3            1             1      1
# ...             ...        ...   ...          ...           ...    ...
# 8123         320000     110000     3            1             1      1
# 8124         135000     119000     1            1             1      4
# 8125         382000     120000     1            1             1      1
# 8126         290000      25000     1            1             1      1
# 8127         290000      25000     1            1             1      1
#
#        max_power                     torque  seats  cartype  No. of years  \
# 0         74 bhp             190Nm@ 2000rpm    5.0   Maruti             7
# 1     103.52 bhp        250Nm@ 1500-2500rpm    5.0    Skoda             7
# 2         78 bhp      12.7@ 2,700(kgm@ rpm)    5.0    Honda            15
# 3         90 bhp   22.4 kgm at 1750-2750rpm    5.0  Hyundai            11
# 4       88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0   Maruti            14
# ...          ...                        ...    ...      ...           ...
# 8123   82.85 bhp           113.7Nm@ 4000rpm    5.0  Hyundai             8
# 8124     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0  Hyundai            14
# 8125    73.9 bhp             190Nm@ 2000rpm    5.0   Maruti            12
# 8126      70 bhp        140Nm@ 1800-3000rpm    5.0     Tata             8
# 8127      70 bhp        140Nm@ 1800-3000rpm    5.0     Tata             8
#
#      Mileage Engine
# 0       23.4   1248
# 1      21.14   1498
# 2       17.7   1497
# 3       23.0   1396
# 4       16.1   1298
# ...      ...    ...
# 8123    18.5   1197
# 8124    16.8   1493
# 8125    19.3   1248
# 8126   23.57   1396
# 8127   23.57   1396
#
# [8128 rows x 13 columns]

# %%
power=data.max_power.str.split(expand=True)
data['Max_power']=power[0]
data=data.drop(['max_power'],axis=1)
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0            450000     145500     1            1             1      1
# 1            370000     120000     1            1             1      2
# 2            158000     140000     3            1             1      3
# 3            225000     127000     1            1             1      1
# 4            130000     120000     3            1             1      1
# ...             ...        ...   ...          ...           ...    ...
# 8123         320000     110000     3            1             1      1
# 8124         135000     119000     1            1             1      4
# 8125         382000     120000     1            1             1      1
# 8126         290000      25000     1            1             1      1
# 8127         290000      25000     1            1             1      1
#
#                          torque  seats  cartype  No. of years Mileage Engine  \
# 0                190Nm@ 2000rpm    5.0   Maruti             7    23.4   1248
# 1           250Nm@ 1500-2500rpm    5.0    Skoda             7   21.14   1498
# 2         12.7@ 2,700(kgm@ rpm)    5.0    Honda            15    17.7   1497
# 3      22.4 kgm at 1750-2750rpm    5.0  Hyundai            11    23.0   1396
# 4         11.5@ 4,500(kgm@ rpm)    5.0   Maruti            14    16.1   1298
# ...                         ...    ...      ...           ...     ...    ...
# 8123           113.7Nm@ 4000rpm    5.0  Hyundai             8    18.5   1197
# 8124  24@ 1,900-2,750(kgm@ rpm)    5.0  Hyundai            14    16.8   1493
# 8125             190Nm@ 2000rpm    5.0   Maruti            12    19.3   1248
# 8126        140Nm@ 1800-3000rpm    5.0     Tata             8   23.57   1396
# 8127        140Nm@ 1800-3000rpm    5.0     Tata             8   23.57   1396
#
#      Max_power
# 0           74
# 1       103.52
# 2           78
# 3           90
# 4         88.2
# ...        ...
# 8123     82.85
# 8124       110
# 8125      73.9
# 8126        70
# 8127        70
#
# [8128 rows x 13 columns]

# %%
data.isnull().sum()
# Out:
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# torque           222
# seats            221
# cartype            0
# No. of years       0
# Mileage          221
# Engine           221
# Max_power        215
# dtype: int64

# %%
data.seats.value_counts()
# Out:
# 5.0     6254
# 7.0     1120
# 8.0      236
# 4.0      133
# 9.0       80
# 6.0       62
# 10.0      19
# 2.0        2
# 14.0       1
# Name: seats, dtype: int64

# %%
data=data.drop(['seats'],axis=1)
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0            450000     145500     1            1             1      1
# 1            370000     120000     1            1             1      2
# 2            158000     140000     3            1             1      3
# 3            225000     127000     1            1             1      1
# 4            130000     120000     3            1             1      1
# ...             ...        ...   ...          ...           ...    ...
# 8123         320000     110000     3            1             1      1
# 8124         135000     119000     1            1             1      4
# 8125         382000     120000     1            1             1      1
# 8126         290000      25000     1            1             1      1
# 8127         290000      25000     1            1             1      1
#
#                          torque  cartype  No. of years Mileage Engine  \
# 0                190Nm@ 2000rpm   Maruti             7    23.4   1248
# 1           250Nm@ 1500-2500rpm    Skoda             7   21.14   1498
# 2         12.7@ 2,700(kgm@ rpm)    Honda            15    17.7   1497
# 3      22.4 kgm at 1750-2750rpm  Hyundai            11    23.0   1396
# 4         11.5@ 4,500(kgm@ rpm)   Maruti            14    16.1   1298
# ...                         ...      ...           ...     ...    ...
# 8123           113.7Nm@ 4000rpm  Hyundai             8    18.5   1197
# 8124  24@ 1,900-2,750(kgm@ rpm)  Hyundai            14    16.8   1493
# 8125             190Nm@ 2000rpm   Maruti            12    19.3   1248
# 8126        140Nm@ 1800-3000rpm     Tata             8   23.57   1396
# 8127        140Nm@ 1800-3000rpm     Tata             8   23.57   1396
#
#      Max_power
# 0           74
# 1       103.52
# 2           78
# 3           90
# 4         88.2
# ...        ...
# 8123     82.85
# 8124       110
# 8125      73.9
# 8126        70
# 8127        70
#
# [8128 rows x 12 columns]

# %%
tor=data.torque.str.split('@',expand=True)
data['Torq']=tor[0]
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0            450000     145500     1            1             1      1
# 1            370000     120000     1            1             1      2
# 2            158000     140000     3            1             1      3
# 3            225000     127000     1            1             1      1
# 4            130000     120000     3            1             1      1
# ...             ...        ...   ...          ...           ...    ...
# 8123         320000     110000     3            1             1      1
# 8124         135000     119000     1            1             1      4
# 8125         382000     120000     1            1             1      1
# 8126         290000      25000     1            1             1      1
# 8127         290000      25000     1            1             1      1
#
#                          torque  cartype  No. of years Mileage Engine  \
# 0                190Nm@ 2000rpm   Maruti             7    23.4   1248
# 1           250Nm@ 1500-2500rpm    Skoda             7   21.14   1498
# 2         12.7@ 2,700(kgm@ rpm)    Honda            15    17.7   1497
# 3      22.4 kgm at 1750-2750rpm  Hyundai            11    23.0   1396
# 4         11.5@ 4,500(kgm@ rpm)   Maruti            14    16.1   1298
# ...                         ...      ...           ...     ...    ...
# 8123           113.7Nm@ 4000rpm  Hyundai             8    18.5   1197
# 8124  24@ 1,900-2,750(kgm@ rpm)  Hyundai            14    16.8   1493
# 8125             190Nm@ 2000rpm   Maruti            12    19.3   1248
# 8126        140Nm@ 1800-3000rpm     Tata             8   23.57   1396
# 8127        140Nm@ 1800-3000rpm     Tata             8   23.57   1396
#
#      Max_power                      Torq
# 0           74                     190Nm
# 1       103.52                     250Nm
# 2           78                      12.7
# 3           90  22.4 kgm at 1750-2750rpm
# 4         88.2                      11.5
# ...        ...                       ...
# 8123     82.85                   113.7Nm
# 8124       110                        24
# 8125      73.9                     190Nm
# 8126        70                     140Nm
# 8127        70                     140Nm
#
# [8128 rows x 13 columns]

# %%
tor=data.Torq.str.split(expand=True)
data['Tor']=tor[0]
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0            450000     145500     1            1             1      1
# 1            370000     120000     1            1             1      2
# 2            158000     140000     3            1             1      3
# 3            225000     127000     1            1             1      1
# 4            130000     120000     3            1             1      1
# ...             ...        ...   ...          ...           ...    ...
# 8123         320000     110000     3            1             1      1
# 8124         135000     119000     1            1             1      4
# 8125         382000     120000     1            1             1      1
# 8126         290000      25000     1            1             1      1
# 8127         290000      25000     1            1             1      1
#
#                          torque  cartype  No. of years Mileage Engine  \
# 0                190Nm@ 2000rpm   Maruti             7    23.4   1248
# 1           250Nm@ 1500-2500rpm    Skoda             7   21.14   1498
# 2         12.7@ 2,700(kgm@ rpm)    Honda            15    17.7   1497
# 3      22.4 kgm at 1750-2750rpm  Hyundai            11    23.0   1396
# 4         11.5@ 4,500(kgm@ rpm)   Maruti            14    16.1   1298
# ...                         ...      ...           ...     ...    ...
# 8123           113.7Nm@ 4000rpm  Hyundai             8    18.5   1197
# 8124  24@ 1,900-2,750(kgm@ rpm)  Hyundai            14    16.8   1493
# 8125             190Nm@ 2000rpm   Maruti            12    19.3   1248
# 8126        140Nm@ 1800-3000rpm     Tata             8   23.57   1396
# 8127        140Nm@ 1800-3000rpm     Tata             8   23.57   1396
#
#      Max_power                      Torq      Tor
# 0           74                     190Nm    190Nm
# 1       103.52                     250Nm    250Nm
# 2           78                      12.7     12.7
# 3           90  22.4 kgm at 1750-2750rpm     22.4
# 4         88.2                      11.5     11.5
# ...        ...                       ...      ...
# 8123     82.85                   113.7Nm  113.7Nm
# 8124       110                        24       24
# 8125      73.9                     190Nm    190Nm
# 8126        70                     140Nm    140Nm
# 8127        70                     140Nm    140Nm
#
# [8128 rows x 14 columns]

# %%
tor=data.Torq.str.split(expand=True)
data['Tor']=tor[0]
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0            450000     145500     1            1             1      1
# 1            370000     120000     1            1             1      2
# 2            158000     140000     3            1             1      3
# 3            225000     127000     1            1             1      1
# 4            130000     120000     3            1             1      1
# ...             ...        ...   ...          ...           ...    ...
# 8123         320000     110000     3            1             1      1
# 8124         135000     119000     1            1             1      4
# 8125         382000     120000     1            1             1      1
# 8126         290000      25000     1            1             1      1
# 8127         290000      25000     1            1             1      1
#
#                          torque  cartype  No. of years Mileage Engine  \
# 0                190Nm@ 2000rpm   Maruti             7    23.4   1248
# 1           250Nm@ 1500-2500rpm    Skoda             7   21.14   1498
# 2         12.7@ 2,700(kgm@ rpm)    Honda            15    17.7   1497
# 3      22.4 kgm at 1750-2750rpm  Hyundai            11    23.0   1396
# 4         11.5@ 4,500(kgm@ rpm)   Maruti            14    16.1   1298
# ...                         ...      ...           ...     ...    ...
# 8123           113.7Nm@ 4000rpm  Hyundai             8    18.5   1197
# 8124  24@ 1,900-2,750(kgm@ rpm)  Hyundai            14    16.8   1493
# 8125             190Nm@ 2000rpm   Maruti            12    19.3   1248
# 8126        140Nm@ 1800-3000rpm     Tata             8   23.57   1396
# 8127        140Nm@ 1800-3000rpm     Tata             8   23.57   1396
#
#      Max_power                      Torq      Tor
# 0           74                     190Nm    190Nm
# 1       103.52                     250Nm    250Nm
# 2           78                      12.7     12.7
# 3           90  22.4 kgm at 1750-2750rpm     22.4
# 4         88.2                      11.5     11.5
# ...        ...                       ...      ...
# 8123     82.85                   113.7Nm  113.7Nm
# 8124       110                        24       24
# 8125      73.9                     190Nm    190Nm
# 8126        70                     140Nm    140Nm
# 8127        70                     140Nm    140Nm
#
# [8128 rows x 14 columns]

# %%
tor=data.Tor.str.split('N',expand=True)
data['torq']=tor[0]

data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0            450000     145500     1            1             1      1
# 1            370000     120000     1            1             1      2
# 2            158000     140000     3            1             1      3
# 3            225000     127000     1            1             1      1
# 4            130000     120000     3            1             1      1
# ...             ...        ...   ...          ...           ...    ...
# 8123         320000     110000     3            1             1      1
# 8124         135000     119000     1            1             1      4
# 8125         382000     120000     1            1             1      1
# 8126         290000      25000     1            1             1      1
# 8127         290000      25000     1            1             1      1
#
#                          torque  cartype  No. of years Mileage Engine  \
# 0                190Nm@ 2000rpm   Maruti             7    23.4   1248
# 1           250Nm@ 1500-2500rpm    Skoda             7   21.14   1498
# 2         12.7@ 2,700(kgm@ rpm)    Honda            15    17.7   1497
# 3      22.4 kgm at 1750-2750rpm  Hyundai            11    23.0   1396
# 4         11.5@ 4,500(kgm@ rpm)   Maruti            14    16.1   1298
# ...                         ...      ...           ...     ...    ...
# 8123           113.7Nm@ 4000rpm  Hyundai             8    18.5   1197
# 8124  24@ 1,900-2,750(kgm@ rpm)  Hyundai            14    16.8   1493
# 8125             190Nm@ 2000rpm   Maruti            12    19.3   1248
# 8126        140Nm@ 1800-3000rpm     Tata             8   23.57   1396
# 8127        140Nm@ 1800-3000rpm     Tata             8   23.57   1396
#
#      Max_power                      Torq      Tor   torq
# 0           74                     190Nm    190Nm    190
# 1       103.52                     250Nm    250Nm    250
# 2           78                      12.7     12.7   12.7
# 3           90  22.4 kgm at 1750-2750rpm     22.4   22.4
# 4         88.2                      11.5     11.5   11.5
# ...        ...                       ...      ...    ...
# 8123     82.85                   113.7Nm  113.7Nm  113.7
# 8124       110                        24       24     24
# 8125      73.9                     190Nm    190Nm    190
# 8126        70                     140Nm    140Nm    140
# 8127        70                     140Nm    140Nm    140
#
# [8128 rows x 15 columns]

# %%
torq=data.torq.str.split('n',expand=True)
data['Torque']=torq[0]
data=data.drop(['torque','Torq','Tor','torq'],axis=1)
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0            450000     145500     1            1             1      1
# 1            370000     120000     1            1             1      2
# 2            158000     140000     3            1             1      3
# 3            225000     127000     1            1             1      1
# 4            130000     120000     3            1             1      1
# ...             ...        ...   ...          ...           ...    ...
# 8123         320000     110000     3            1             1      1
# 8124         135000     119000     1            1             1      4
# 8125         382000     120000     1            1             1      1
# 8126         290000      25000     1            1             1      1
# 8127         290000      25000     1            1             1      1
#
#       cartype  No. of years Mileage Engine Max_power Torque
# 0      Maruti             7    23.4   1248        74    190
# 1       Skoda             7   21.14   1498    103.52    250
# 2       Honda            15    17.7   1497        78   12.7
# 3     Hyundai            11    23.0   1396        90   22.4
# 4      Maruti            14    16.1   1298      88.2   11.5
# ...       ...           ...     ...    ...       ...    ...
# 8123  Hyundai             8    18.5   1197     82.85  113.7
# 8124  Hyundai            14    16.8   1493       110     24
# 8125   Maruti            12    19.3   1248      73.9    190
# 8126     Tata             8   23.57   1396        70    140
# 8127     Tata             8   23.57   1396        70    140
#
# [8128 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# cartype            0
# No. of years       0
# Mileage          221
# Engine           221
# Max_power        215
# Torque           222
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0            450000     145500     1            1             1      1
# 1            370000     120000     1            1             1      2
# 2            158000     140000     3            1             1      3
# 3            225000     127000     1            1             1      1
# 4            130000     120000     3            1             1      1
# ...             ...        ...   ...          ...           ...    ...
# 8123         320000     110000     3            1             1      1
# 8124         135000     119000     1            1             1      4
# 8125         382000     120000     1            1             1      1
# 8126         290000      25000     1            1             1      1
# 8127         290000      25000     1            1             1      1
#
#       cartype  No. of years Mileage Engine Max_power Torque
# 0      Maruti             7    23.4   1248        74    190
# 1       Skoda             7   21.14   1498    103.52    250
# 2       Honda            15    17.7   1497        78   12.7
# 3     Hyundai            11    23.0   1396        90   22.4
# 4      Maruti            14    16.1   1298      88.2   11.5
# ...       ...           ...     ...    ...       ...    ...
# 8123  Hyundai             8    18.5   1197     82.85  113.7
# 8124  Hyundai            14    16.8   1493       110     24
# 8125   Maruti            12    19.3   1248      73.9    190
# 8126     Tata             8   23.57   1396        70    140
# 8127     Tata             8   23.57   1396        70    140
#
# [7906 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# cartype          0
# No. of years     0
# Mileage          0
# Engine           0
# Max_power        0
# Torque           0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   selling_price  7906 non-null   int64
#  1   km_driven      7906 non-null   int64
#  2   fuel           7906 non-null   int32
#  3   seller_type    7906 non-null   int32
#  4   transmission   7906 non-null   int32
#  5   owner          7906 non-null   int64
#  6   cartype        7906 non-null   object
#  7   No. of years   7906 non-null   int64
#  8   Mileage        7906 non-null   object
#  9   Engine         7906 non-null   object
#  10  Max_power      7906 non-null   object
#  11  Torque         7906 non-null   object
# dtypes: int32(3), int64(4), object(5)
# memory usage: 555.9+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr = data.corr()
plt.figure(figsize=(12,6))
sns.heatmap(corr,annot=True,cmap='YlGn')
# Out:
# <AxesSubplot:>

# %%
data=data.drop('cartype',axis=1)

# %%
Torque=data.Torque.str.split('k',expand=True)
data['torque']=Torque[0]
data=data.drop(['Torque'],axis=1)
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0            450000     145500     1            1             1      1
# 1            370000     120000     1            1             1      2
# 2            158000     140000     3            1             1      3
# 3            225000     127000     1            1             1      1
# 4            130000     120000     3            1             1      1
# ...             ...        ...   ...          ...           ...    ...
# 8123         320000     110000     3            1             1      1
# 8124         135000     119000     1            1             1      4
# 8125         382000     120000     1            1             1      1
# 8126         290000      25000     1            1             1      1
# 8127         290000      25000     1            1             1      1
#
#       No. of years Mileage Engine Max_power torque
# 0                7    23.4   1248        74    190
# 1                7   21.14   1498    103.52    250
# 2               15    17.7   1497        78   12.7
# 3               11    23.0   1396        90   22.4
# 4               14    16.1   1298      88.2   11.5
# ...            ...     ...    ...       ...    ...
# 8123             8    18.5   1197     82.85  113.7
# 8124            14    16.8   1493       110     24
# 8125            12    19.3   1248      73.9    190
# 8126             8   23.57   1396        70    140
# 8127             8   23.57   1396        70    140
#
# [7906 rows x 11 columns]

# %%
torque=data.torque.str.split('(',expand=True)
data['Torque']=torque[0]
data=data.drop(['torque'],axis=1)
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0            450000     145500     1            1             1      1
# 1            370000     120000     1            1             1      2
# 2            158000     140000     3            1             1      3
# 3            225000     127000     1            1             1      1
# 4            130000     120000     3            1             1      1
# ...             ...        ...   ...          ...           ...    ...
# 8123         320000     110000     3            1             1      1
# 8124         135000     119000     1            1             1      4
# 8125         382000     120000     1            1             1      1
# 8126         290000      25000     1            1             1      1
# 8127         290000      25000     1            1             1      1
#
#       No. of years Mileage Engine Max_power Torque
# 0                7    23.4   1248        74    190
# 1                7   21.14   1498    103.52    250
# 2               15    17.7   1497        78   12.7
# 3               11    23.0   1396        90   22.4
# 4               14    16.1   1298      88.2   11.5
# ...            ...     ...    ...       ...    ...
# 8123             8    18.5   1197     82.85  113.7
# 8124            14    16.8   1493       110     24
# 8125            12    19.3   1248      73.9    190
# 8126             8   23.57   1396        70    140
# 8127             8   23.57   1396        70    140
#
# [7906 rows x 11 columns]

# %%
data=data.apply(pd.to_numeric)
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0            450000     145500     1            1             1      1
# 1            370000     120000     1            1             1      2
# 2            158000     140000     3            1             1      3
# 3            225000     127000     1            1             1      1
# 4            130000     120000     3            1             1      1
# ...             ...        ...   ...          ...           ...    ...
# 8123         320000     110000     3            1             1      1
# 8124         135000     119000     1            1             1      4
# 8125         382000     120000     1            1             1      1
# 8126         290000      25000     1            1             1      1
# 8127         290000      25000     1            1             1      1
#
#       No. of years  Mileage  Engine  Max_power  Torque
# 0                7    23.40    1248      74.00   190.0
# 1                7    21.14    1498     103.52   250.0
# 2               15    17.70    1497      78.00    12.7
# 3               11    23.00    1396      90.00    22.4
# 4               14    16.10    1298      88.20    11.5
# ...            ...      ...     ...        ...     ...
# 8123             8    18.50    1197      82.85   113.7
# 8124            14    16.80    1493     110.00    24.0
# 8125            12    19.30    1248      73.90   190.0
# 8126             8    23.57    1396      70.00   140.0
# 8127             8    23.57    1396      70.00   140.0
#
# [7906 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   selling_price  7906 non-null   int64
#  1   km_driven      7906 non-null   int64
#  2   fuel           7906 non-null   int32
#  3   seller_type    7906 non-null   int32
#  4   transmission   7906 non-null   int32
#  5   owner          7906 non-null   int64
#  6   No. of years   7906 non-null   int64
#  7   Mileage        7906 non-null   float64
#  8   Engine         7906 non-null   int64
#  9   Max_power      7906 non-null   float64
#  10  Torque         7906 non-null   float64
# dtypes: float64(3), int32(3), int64(5)
# memory usage: 648.5 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr = data.corr()
plt.figure(figsize=(12,12))
sns.heatmap(corr,annot=True,cmap='YlGn')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(corr)

# %%
X=data.drop(['selling_price'],axis=1)
y=data.selling_price

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
etr.feature_importances_
# Out:
# array([0.0456763 , 0.01801227, 0.03198411, 0.26923485, 0.011323  ,
#        0.14672364, 0.02205412, 0.05385059, 0.25347956, 0.14766155])

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=X.columns,y=etr.feature_importances_)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
X_train.shape,X_test.shape
# Out:
# ((6324, 10), (1582, 10))

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
import numpy as np

from sklearn.model_selection import RandomizedSearchCV

rs = RandomizedSearchCV(RandomForestRegressor(),{
    'n_estimators':[int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)],
    'max_features':['auto','sqrt'],
    'max_depth':[int(x) for x in np.linspace(5,30, num = 6)],
    'min_samples_split':[2,5,10,15,100],
    'min_samples_leaf':[1,2,5,10]}
     )

# %%
rs.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]})

# %%
rs.best_params_
# Out:
# {'n_estimators': 1100,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 30}

# %%
param = pd.DataFrame(rs.cv_results_)
param
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       2.269352      0.116526         0.097712        0.003245
# 1       5.278799      0.141659         0.225624        0.004619
# 2       4.535773      0.182256         0.184945        0.004151
# 3       8.325852      0.417824         0.154673        0.004469
# 4       0.921042      0.007149         0.045480        0.003427
# 5       8.893594      0.068452         0.330883        0.004796
# 6      11.626506      0.016466         0.217564        0.001833
# 7       0.977606      0.009085         0.043963        0.007231
# 8       0.589914      0.002101         0.011254        0.005687
# 9       4.303717      0.035881         0.083443        0.007466
#
#   param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                500                      15                     10
# 1               1200                      10                     10
# 2                700                       5                      1
# 3                700                      10                      5
# 4                200                      15                      5
# 5               1100                       2                      1
# 6               1200                      15                      2
# 7                200                      15                      2
# 8                100                       5                      1
# 9                300                       5                      1
#
#   param_max_features param_max_depth  \
# 0               sqrt              25
# 1               sqrt              30
# 2               sqrt              20
# 3               auto              15
# 4               sqrt              15
# 5               sqrt              30
# 6               auto              10
# 7               sqrt              30
# 8               auto               5
# 9               auto              30
#
#                                               params  split0_test_score  \
# 0  {'n_estimators': 500, 'min_samples_split': 15,...           0.946488
# 1  {'n_estimators': 1200, 'min_samples_split': 10...           0.947240
# 2  {'n_estimators': 700, 'min_samples_split': 5, ...           0.973980
# 3  {'n_estimators': 700, 'min_samples_split': 10,...           0.963745
# 4  {'n_estimators': 200, 'min_samples_split': 15,...           0.957764
# 5  {'n_estimators': 1100, 'min_samples_split': 2,...           0.975072
# 6  {'n_estimators': 1200, 'min_samples_split': 15...           0.967104
# 7  {'n_estimators': 200, 'min_samples_split': 15,...           0.963894
# 8  {'n_estimators': 100, 'min_samples_split': 5, ...           0.944015
# 9  {'n_estimators': 300, 'min_samples_split': 5, ...           0.975455
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.952271           0.937344           0.951290           0.895037
# 1           0.954619           0.939312           0.950556           0.894872
# 2           0.975997           0.973253           0.975779           0.927081
# 3           0.968648           0.959450           0.965008           0.904464
# 4           0.963835           0.950682           0.958032           0.905242
# 5           0.976555           0.974893           0.976794           0.928456
# 6           0.969570           0.964212           0.966796           0.917053
# 7           0.970647           0.961767           0.966880           0.915680
# 8           0.954016           0.945118           0.952808           0.900057
# 9           0.974062           0.974455           0.972796           0.931595
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.936486        0.021388               10
# 1         0.937320        0.021811                9
# 2         0.965218        0.019097                3
# 3         0.952263        0.024080                6
# 4         0.947111        0.021346                7
# 5         0.966354        0.018964                1
# 6         0.956947        0.020019                4
# 7         0.955774        0.020268                5
# 8         0.939203        0.019976                8
# 9         0.965673        0.017060                2

# %%
param[['param_n_estimators','param_min_samples_split','param_min_samples_leaf','param_max_features','param_max_depth','mean_test_score']]
# Out:
#   param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                500                      15                     10
# 1               1200                      10                     10
# 2                700                       5                      1
# 3                700                      10                      5
# 4                200                      15                      5
# 5               1100                       2                      1
# 6               1200                      15                      2
# 7                200                      15                      2
# 8                100                       5                      1
# 9                300                       5                      1
#
#   param_max_features param_max_depth  mean_test_score
# 0               sqrt              25         0.936486
# 1               sqrt              30         0.937320
# 2               sqrt              20         0.965218
# 3               auto              15         0.952263
# 4               sqrt              15         0.947111
# 5               sqrt              30         0.966354
# 6               auto              10         0.956947
# 7               sqrt              30         0.955774
# 8               auto               5         0.939203
# 9               auto              30         0.965673

# %%
model = RandomForestRegressor(n_estimators=1100,
 min_samples_split= 2,
 min_samples_leaf= 1,
 max_features= 'sqrt',
 max_depth= 30)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=30, max_features='sqrt', n_estimators=1100)

# %%
from sklearn import metrics
pred=model.predict(X_test)
metrics.r2_score(pred,y_test)
# Out:
# 0.9729275928681332

# %%
plt.scatter(y_test,pred)
