# %%
import pandas as pd

# %%
data = pd.read_csv('car data.csv')
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 16.5+ KB

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data.corr()
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven     Owner
# Year           1.000000       0.236141      -0.047584   -0.524342 -0.182104
# Selling_Price  0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price -0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000  0.089216
# Owner         -0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
data = data.drop('Car_Name',axis=1)
data
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# 2         Manual      0
# 3         Manual      0
# 4         Manual      0
# ..           ...    ...
# 296       Manual      0
# 297       Manual      0
# 298       Manual      0
# 299       Manual      0
# 300       Manual      0
#
# [301 rows x 8 columns]

# %%
data['No_of_years']= 2021-data['Year']
data
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  No_of_years
# 0         Manual      0            7
# 1         Manual      0            8
# 2         Manual      0            4
# 3         Manual      0           10
# 4         Manual      0            7
# ..           ...    ...          ...
# 296       Manual      0            5
# 297       Manual      0            6
# 298       Manual      0           12
# 299       Manual      0            4
# 300       Manual      0            5
#
# [301 rows x 9 columns]

# %%
data= data.drop('Year',axis=1)

# %%
data
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  No_of_years
# 0         Manual      0            7
# 1         Manual      0            8
# 2         Manual      0            4
# 3         Manual      0           10
# 4         Manual      0            7
# ..           ...    ...          ...
# 296       Manual      0            5
# 297       Manual      0            6
# 298       Manual      0           12
# 299       Manual      0            4
# 300       Manual      0            5
#
# [301 rows x 8 columns]

# %%
data.Fuel_Type.value_counts()
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
data.Seller_Type.value_counts()
# Out:
# Dealer        195
# Individual    106
# Name: Seller_Type, dtype: int64

# %%
data.Transmission.value_counts()
# Out:
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Fuel_Type']=le.fit_transform(data['Fuel_Type'])
data.Seller_Type = le.fit_transform(data.Seller_Type)
data.Transmission= le.fit_transform(data.Transmission)
data
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            0
# 1             4.75           9.54       43000          1            0
# 2             7.25           9.85        6900          2            0
# 3             2.85           4.15        5200          2            0
# 4             4.60           6.87       42450          1            0
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          1            0
# 297           4.00           5.90       60000          2            0
# 298           3.35          11.00       87934          2            0
# 299          11.50          12.50        9000          1            0
# 300           5.30           5.90        5464          2            0
#
#      Transmission  Owner  No_of_years
# 0               1      0            7
# 1               1      0            8
# 2               1      0            4
# 3               1      0           10
# 4               1      0            7
# ..            ...    ...          ...
# 296             1      0            5
# 297             1      0            6
# 298             1      0           12
# 299             1      0            4
# 300             1      0            5
#
# [301 rows x 8 columns]

# %%
import seaborn as sns
sns.pairplot(data)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
corr = data.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
data.Owner.value_counts()
# Out:
# 0    290
# 1     10
# 3      1
# Name: Owner, dtype: int64

# %%
data.No_of_years.value_counts()
# Out:
# 6     61
# 5     50
# 7     38
# 4     35
# 8     33
# 9     23
# 10    19
# 11    15
# 13     7
# 12     6
# 16     4
# 15     4
# 18     2
# 14     2
# 17     1
# 3      1
# Name: No_of_years, dtype: int64

# %%
X=data.drop('Selling_Price',axis=1)
y = data.Selling_Price
X.shape,y.shape
# Out:
# ((301, 7), (301,))

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr = ExtraTreesRegressor()
etr.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
etr.feature_importances_
# Out:
# array([0.46456698, 0.03515903, 0.12018894, 0.23014757, 0.06690591,
#        0.00119099, 0.08184059])

# %%
plt.figure(figsize=(12,12))
sns.barplot(x=X.columns,y=etr.feature_importances_)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
X_train.shape,X_test.shape
# Out:
# ((240, 7), (61, 7))

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
import numpy as np

from sklearn.model_selection import RandomizedSearchCV

rs = RandomizedSearchCV(RandomForestRegressor(),{
    'n_estimators':[int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)],
    'max_features':['auto','sqrt'],
    'max_depth':[int(x) for x in np.linspace(5,30, num = 6)],
    'min_samples_split':[2,5,10,15,100],
    'min_samples_leaf':[1,2,5,10]}
     )

# %%
rs.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]})

# %%
rs.best_params_
# Out:
# {'n_estimators': 1000,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 15}

# %%
param = pd.DataFrame(rs.cv_results_)
param
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.124198      0.013269         0.007815        0.000241
# 1       0.553816      0.005375         0.030158        0.001045
# 2       1.285245      0.141504         0.071427        0.021927
# 3       0.231669      0.001918         0.013930        0.001057
# 4       1.418247      0.016256         0.061764        0.000200
# 5       1.348051      0.007649         0.063673        0.004031
# 6       0.492629      0.001289         0.024255        0.000254
# 7       1.233717      0.002668         0.065074        0.002825
# 8       0.711703      0.003928         0.036274        0.001888
# 9       0.118283      0.001614         0.008420        0.001799
#
#   param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                100                      10                      1
# 1                500                      10                     10
# 2               1000                      10                     10
# 3                200                      10                      1
# 4               1000                       2                      1
# 5               1100                       5                      5
# 6                400                       2                      1
# 7               1100                      15                      5
# 8                600                      15                     10
# 9                100                      15                     10
#
#   param_max_features param_max_depth  \
# 0               sqrt              25
# 1               sqrt              10
# 2               auto              25
# 3               sqrt              10
# 4               auto              15
# 5               auto              10
# 6               auto               5
# 7               sqrt              20
# 8               auto              30
# 9               auto               5
#
#                                               params  split0_test_score  \
# 0  {'n_estimators': 100, 'min_samples_split': 10,...           0.734281
# 1  {'n_estimators': 500, 'min_samples_split': 10,...           0.528226
# 2  {'n_estimators': 1000, 'min_samples_split': 10...           0.669756
# 3  {'n_estimators': 200, 'min_samples_split': 10,...           0.750633
# 4  {'n_estimators': 1000, 'min_samples_split': 2,...           0.877602
# 5  {'n_estimators': 1100, 'min_samples_split': 5,...           0.834609
# 6  {'n_estimators': 400, 'min_samples_split': 2, ...           0.873316
# 7  {'n_estimators': 1100, 'min_samples_split': 15...           0.648481
# 8  {'n_estimators': 600, 'min_samples_split': 15,...           0.666674
# 9  {'n_estimators': 100, 'min_samples_split': 15,...           0.675010
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.925076           0.757506           0.841926           0.952353
# 1           0.796838           0.435639           0.721307           0.848327
# 2           0.877702           0.549133           0.605095           0.934329
# 3           0.912469           0.729870           0.828831           0.943727
# 4           0.969860           0.885254           0.906848           0.975583
# 5           0.959844           0.718003           0.710982           0.909828
# 6           0.956696           0.885081           0.893804           0.966569
# 7           0.869905           0.535392           0.806872           0.894025
# 8           0.878774           0.545095           0.602527           0.936564
# 9           0.892099           0.551544           0.612976           0.934286
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.842228        0.086973                3
# 1         0.666068        0.158410               10
# 2         0.727203        0.151968                8
# 3         0.833106        0.084868                4
# 4         0.923029        0.041731                1
# 5         0.826653        0.099906                5
# 6         0.915093        0.038678                2
# 7         0.750935        0.137632                6
# 8         0.725927        0.154382                9
# 9         0.733183        0.152659                7

# %%
param[['param_n_estimators','param_min_samples_split','param_min_samples_leaf','param_max_features','param_max_depth','mean_test_score']]
# Out:
#   param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                100                      10                      1
# 1                500                      10                     10
# 2               1000                      10                     10
# 3                200                      10                      1
# 4               1000                       2                      1
# 5               1100                       5                      5
# 6                400                       2                      1
# 7               1100                      15                      5
# 8                600                      15                     10
# 9                100                      15                     10
#
#   param_max_features param_max_depth  mean_test_score
# 0               sqrt              25         0.842228
# 1               sqrt              10         0.666068
# 2               auto              25         0.727203
# 3               sqrt              10         0.833106
# 4               auto              15         0.923029
# 5               auto              10         0.826653
# 6               auto               5         0.915093
# 7               sqrt              20         0.750935
# 8               auto              30         0.725927
# 9               auto               5         0.733183

# %%
model = RandomForestRegressor(n_estimators=1000,
 min_samples_split= 2,
 min_samples_leaf= 1,
 max_features= 'auto',
 max_depth= 15)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=15, n_estimators=1000)

# %%
from sklearn import metrics
pred=model.predict(X_test)
metrics.r2_score(pred,y_test)
# Out:
# 0.9552490345483216

# %%
metrics.mean_absolute_error(y_test,pred)
# Out:
# 0.6039591848816029

# %%
metrics.mean_squared_error(y_test,pred)
# Out:
# 1.030774386403051

# %%
plt.scatter(y_test,pred)
