# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('CAR DETAILS FROM CAR DEKHO.csv')
data
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 0     Petrol  Individual       Manual   First Owner
# 1     Petrol  Individual       Manual   First Owner
# 2     Diesel  Individual       Manual   First Owner
# 3     Petrol  Individual       Manual   First Owner
# 4     Diesel  Individual       Manual  Second Owner
# ...      ...         ...          ...           ...
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner
#
# [4340 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 186.5+ KB

# %%
data.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
data.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
data.fuel.value_counts()
# Out:
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: fuel, dtype: int64

# %%
data.seller_type.value_counts()
# Out:
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: seller_type, dtype: int64

# %%
data.transmission.value_counts()
# Out:
# Manual       3892
# Automatic     448
# Name: transmission, dtype: int64

# %%
data.owner.value_counts()
# Out:
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: owner, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data.fuel=le.fit_transform(data.fuel)
data.seller_type=le.fit_transform(data.seller_type)
data.transmission=le.fit_transform(data.transmission)
data.owner=le.fit_transform(data.owner)
data
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#       fuel  seller_type  transmission  owner
# 0        4            1             1      0
# 1        4            1             1      0
# 2        1            1             1      0
# 3        4            1             1      0
# 4        1            1             1      2
# ...    ...          ...           ...    ...
# 4335     1            1             1      2
# 4336     1            1             1      2
# 4337     4            1             1      2
# 4338     1            1             1      0
# 4339     4            1             1      0
#
# [4340 rows x 8 columns]

# %%
data['No of Years']=2021-data.year
data
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#       fuel  seller_type  transmission  owner  No of Years
# 0        4            1             1      0           14
# 1        4            1             1      0           14
# 2        1            1             1      0            9
# 3        4            1             1      0            4
# 4        1            1             1      2            7
# ...    ...          ...           ...    ...          ...
# 4335     1            1             1      2            7
# 4336     1            1             1      2            7
# 4337     4            1             1      2           12
# 4338     1            1             1      0            5
# 4339     4            1             1      0            5
#
# [4340 rows x 9 columns]

# %%
data=data.drop(['name','year'],axis=1)
data
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0             60000      70000     4            1             1      0
# 1            135000      50000     4            1             1      0
# 2            600000     100000     1            1             1      0
# 3            250000      46000     4            1             1      0
# 4            450000     141000     1            1             1      2
# ...             ...        ...   ...          ...           ...    ...
# 4335         409999      80000     1            1             1      2
# 4336         409999      80000     1            1             1      2
# 4337         110000      83000     4            1             1      2
# 4338         865000      90000     1            1             1      0
# 4339         225000      40000     4            1             1      0
#
#       No of Years
# 0              14
# 1              14
# 2               9
# 3               4
# 4               7
# ...           ...
# 4335            7
# 4336            7
# 4337           12
# 4338            5
# 4339            5
#
# [4340 rows x 7 columns]

# %%
corr=data.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,6))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)

# %%
X=data.drop(['selling_price','owner'],axis=1)
y=data.selling_price
X.shape,y.shape
# Out:
# ((4340, 5), (4340,))

# %%
from sklearn.ensemble import ExtraTreesRegressor
et = ExtraTreesRegressor()
et.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
et.feature_importances_
# Out:
# array([0.2595087 , 0.13068073, 0.06308421, 0.2961163 , 0.25061006])

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=X.columns,y=et.feature_importances_)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
X_train.shape,X_test.shape
# Out:
# ((3472, 5), (868, 5))

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
from sklearn.model_selection import RandomizedSearchCV
rsc = RandomizedSearchCV(RandomForestRegressor(),{
    'n_estimators':[int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)],
    'max_features':['auto','sqrt'],
    'max_depth':[int(x) for x in np.linspace(5,30, num = 6)],
    'min_samples_split':[2,5,10,15,100],
    'min_samples_leaf':[1,2,5,10]}
)

# %%
rsc.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]})

# %%
rsc.best_params_
# Out:
# {'n_estimators': 1100,
#  'min_samples_split': 10,
#  'min_samples_leaf': 5,
#  'max_features': 'sqrt',
#  'max_depth': 15}

# %%
param = pd.DataFrame(rsc.cv_results_)
param
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       3.317789      0.591311         0.105646        0.003192
# 1       0.709089      0.010819         0.032066        0.000311
# 2       1.279249      0.100685         0.052374        0.003968
# 3       0.560459      0.006574         0.026855        0.002723
# 4       3.505834      0.275125         0.143155        0.015392
# 5       2.012805      0.015820         0.108465        0.005677
# 6       0.237530      0.007601         0.015562        0.004491
# 7       2.348306      0.021279         0.134701        0.007592
# 8       0.651953      0.010207         0.030253        0.003487
# 9       1.279934      0.006763         0.074924        0.004631
#
#   param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                800                      15                      2
# 1                300                     100                      5
# 2                500                     100                      2
# 3                200                       5                     10
# 4               1000                      15                      2
# 5               1200                       2                      5
# 6                100                     100                      5
# 7               1100                      10                      5
# 8                300                     100                      2
# 9                600                      10                      5
#
#   param_max_features param_max_depth  \
# 0               auto              10
# 1               auto              20
# 2               auto              15
# 3               auto              20
# 4               auto              15
# 5               sqrt               5
# 6               auto              30
# 7               sqrt              15
# 8               auto               5
# 9               sqrt              15
#
#                                               params  split0_test_score  \
# 0  {'n_estimators': 800, 'min_samples_split': 15,...           0.652373
# 1  {'n_estimators': 300, 'min_samples_split': 100...           0.601065
# 2  {'n_estimators': 500, 'min_samples_split': 100...           0.599701
# 3  {'n_estimators': 200, 'min_samples_split': 5, ...           0.659037
# 4  {'n_estimators': 1000, 'min_samples_split': 15...           0.652927
# 5  {'n_estimators': 1200, 'min_samples_split': 2,...           0.645908
# 6  {'n_estimators': 100, 'min_samples_split': 100...           0.599518
# 7  {'n_estimators': 1100, 'min_samples_split': 10...           0.671598
# 8  {'n_estimators': 300, 'min_samples_split': 100...           0.595933
# 9  {'n_estimators': 600, 'min_samples_split': 10,...           0.670324
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.592889           0.437964           0.714364           0.642954
# 1           0.553571           0.392319           0.597916           0.604962
# 2           0.554328           0.390642           0.595582           0.605111
# 3           0.554651           0.431077           0.673317           0.658237
# 4           0.590769           0.437956           0.714747           0.645903
# 5           0.586197           0.443041           0.681362           0.687767
# 6           0.552029           0.389723           0.591141           0.607946
# 7           0.597759           0.455168           0.701754           0.694201
# 8           0.551802           0.389803           0.592246           0.611048
# 9           0.597646           0.453209           0.701439           0.692533
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.608109        0.093429                5
# 1         0.549966        0.080994                7
# 2         0.549073        0.081234                8
# 3         0.595264        0.092446                6
# 4         0.608460        0.093873                4
# 5         0.608855        0.090404                3
# 6         0.548072        0.081457               10
# 7         0.624096        0.092122                1
# 8         0.548167        0.081573                9
# 9         0.623030        0.092411                2

# %%
param[['param_n_estimators','param_min_samples_split',
       'param_min_samples_leaf','param_max_features','param_max_depth','mean_test_score']]
# Out:
#   param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                800                      15                      2
# 1                300                     100                      5
# 2                500                     100                      2
# 3                200                       5                     10
# 4               1000                      15                      2
# 5               1200                       2                      5
# 6                100                     100                      5
# 7               1100                      10                      5
# 8                300                     100                      2
# 9                600                      10                      5
#
#   param_max_features param_max_depth  mean_test_score
# 0               auto              10         0.608109
# 1               auto              20         0.549966
# 2               auto              15         0.549073
# 3               auto              20         0.595264
# 4               auto              15         0.608460
# 5               sqrt               5         0.608855
# 6               auto              30         0.548072
# 7               sqrt              15         0.624096
# 8               auto               5         0.548167
# 9               sqrt              15         0.623030

# %%
rf = RandomForestRegressor(n_estimators= 100,
 min_samples_split=5,
 min_samples_leaf= 2,
 max_features='sqrt',
 max_depth= 15)
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=15, max_features='sqrt', min_samples_leaf=2,
#                       min_samples_split=5)

# %%
from sklearn import metrics
pred=rf.predict(X_test)
score = metrics.r2_score(y_test,pred)
score
# Out:
# 0.7555734903449837

# %%
plt.scatter(y_test,pred)
